# %% [markdown]
# # Scaling Techniques
#
# ### Standardization
# #### 1.) Standard Scaler
#
#
# ### Normalization
# #### 1.) Min max Scaler
# #### 2.) Min abs Scaler
# #### 3.) Robust Scaler

# %% [markdown]
# ## Standardization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df2=df.iloc[:,2:]

# %%
df2
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(df2.iloc[:,:2], df2.iloc[:,-1], test_size=0.2)

# %%
X_train.head()
# Out:
#      Age  EstimatedSalary
# 292   55            39000
# 82    20            49000
# 326   41            72000
# 237   37            80000
# 275   57            74000

# %%
X_test.head()
# Out:
#      Age  EstimatedSalary
# 137   30           107000
# 102   32            86000
# 362   47            50000
# 96    35            25000
# 132   30            87000

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

ss.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_ss=ss.transform(X_train)
X_test_ss=ss.transform(X_test)

# %%
X_train_ss
# Out:
# array([[ 1.6766585 , -0.89005883],
#        [-1.71910555, -0.60180984],
#        [ 0.31835288,  0.06116283],
#        [-0.06973444,  0.29176202],
#        [ 1.87070216,  0.11881263],
#        [ 0.02728739, -0.57298494],
#        [ 0.22133105,  0.06116283],
#        [ 0.60941837,  1.99243106],
#        [-0.55484359,  1.35828328],
#        [ 0.90048386, -0.65945964],
#        [ 0.31835288,  0.06116283],
#        [ 0.99750569,  0.11881263],
#        [ 0.51239654,  1.21415879],
#        [ 0.12430922,  0.03233793],
#        [ 0.51239654,  1.70418207],
#        [ 0.80346203,  1.35828328],
#        [-0.94293091, -1.09183312],
#        [-1.42804006, -1.43773191],
#        [-0.65186542,  0.55118611],
#        [ 0.02728739, -0.42886045],
#        [-0.74888725,  0.26293712],
#        [ 0.22133105, -0.25591106],
#        [ 0.12430922, -0.80358413],
#        [ 0.90048386, -1.35125721],
#        [-1.71910555,  0.11881263],
#        [ 0.80346203, -1.09183312],
#        [ 0.12430922,  0.20528733],
# ...

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  320.000000       320.000000
# mean    37.718750     69878.125000
# std     10.323101     34746.563253
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     68000.000000
# 75%     45.250000     88000.000000
# max     60.000000    150000.000000

# %%
X_train_ss=pd.DataFrame(X_train_ss, columns=X_train.columns)

# %%
X_train_ss
# Out:
#           Age  EstimatedSalary
# 0    1.676659        -0.890059
# 1   -1.719106        -0.601810
# 2    0.318353         0.061163
# 3   -0.069734         0.291762
# 4    1.870702         0.118813
# ..        ...              ...
# 315 -0.263778        -1.351257
# 316 -1.525062        -0.198261
# 317 -0.263778        -0.342386
# 318 -0.069734         2.136556
# 319 -1.136975         0.407062
#
# [320 rows x 2 columns]

# %%
np.round(X_train_ss.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean     0.0             -0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.7             -0.8
# 50%     -0.1             -0.1
# 75%      0.7              0.5
# max      2.2              2.3

# %% [markdown]
# ### Effect of Standardization

# %% [markdown]
# ### Scatter

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.scatter(X_train["Age"], X_train["EstimatedSalary"])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_ss["Age"], X_train_ss["EstimatedSalary"])
ax2.set_title("After Scaling")
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %% [markdown]
# ### Kde

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.set_title("Before Scaling")
sns.kdeplot(X_train["Age"], ax=ax1)
sns.kdeplot(X_train["EstimatedSalary"], ax=ax1)

ax2.set_title("After Scaling")
sns.kdeplot(X_train_ss["Age"], ax=ax2)
sns.kdeplot(X_train_ss["EstimatedSalary"], ax=ax2)
# Out:
# <Axes: title={'center': 'After Scaling'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Comparsion of Distm

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.set_title("Age dist before scaling")
sns.kdeplot(X_train["Age"], ax=ax1)

ax2.set_title("Age dist after Scaling")
sns.kdeplot(X_train_ss["Age"], ax=ax2)
# Out:
# <Axes: title={'center': 'Age dist after Scaling'}, xlabel='Age', ylabel='Density'>

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.set_title("EstimatedSalary dist before scaling")
sns.kdeplot(X_train["EstimatedSalary"], ax=ax1)

ax2.set_title("EstimatedSalary dist after Scaling")
sns.kdeplot(X_train_ss["EstimatedSalary"], ax=ax2)
# Out:
# <Axes: title={'center': 'EstimatedSalary dist after Scaling'}, xlabel='EstimatedSalary', ylabel='Density'>

# %%
sns.scatterplot(x=X_train["Age"], y=X_train["EstimatedSalary"])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(x=X_train_ss["Age"], y=X_train_ss["EstimatedSalary"])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# #### Normalization Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mm= MinMaxScaler()
X_train_mm=pd.DataFrame(mm.fit_transform(X_train), columns=X_train.columns)
X_test_mm=pd.DataFrame(mm.transform(X_test), columns=X_test.columns)

# %%
X_train_mm.shape
# Out:
# (320, 2)

# %%
X_test_mm.shape
# Out:
# (80, 2)

# %%
X_train_mm.describe()
# Out:
#               Age  EstimatedSalary
# count  320.000000       320.000000
# mean     0.469494         0.406505
# std      0.245788         0.257382
# min      0.000000         0.000000
# 25%      0.285714         0.207407
# 50%      0.452381         0.392593
# 75%      0.648810         0.540741
# max      1.000000         1.000000

# %% [markdown]
# ### Effect of Normalization

# %% [markdown]
# ##### Scatter

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.scatter(X_train["Age"], X_train["EstimatedSalary"])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_mm["Age"], X_train_mm["EstimatedSalary"])
ax2.set_title("After Scaling")
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %% [markdown]
# #### Kde

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.set_title("Before Scaling")
sns.kdeplot(X_train["Age"], ax=ax1)
sns.kdeplot(X_train["EstimatedSalary"], ax=ax1)



ax2.set_title("After Scaling")
sns.kdeplot(X_train_mm["Age"], ax=ax2)
sns.kdeplot(X_train_mm["EstimatedSalary"], ax=ax2)
# Out:
# <Axes: title={'center': 'After Scaling'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Comparsion of Dist

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.set_title("Age dist before scaling")
sns.kdeplot(X_train["Age"], ax=ax1)

ax2.set_title("Age dist after Scaling")
sns.kdeplot(X_train_mm["Age"], ax=ax2)
# Out:
# <AxesSubplot:title={'center':'Age dist after Scaling'}, xlabel='Age', ylabel='Density'>

# %%
fig,(ax1, ax2)= plt.subplots(ncols=2)

ax1.set_title("EstimatedSalary dist before scaling")
sns.kdeplot(X_train["EstimatedSalary"], ax=ax1)

ax2.set_title("EstimatedSalary dist after Scaling")
sns.kdeplot(X_train_mm["EstimatedSalary"], ax=ax2)
# Out:
# <AxesSubplot:title={'center':'EstimatedSalary dist after Scaling'}, xlabel='EstimatedSalary', ylabel='Density'>

# %% [markdown]
# ## Maxabs Scaler
#
# Max absolute scaler is useful if there is spare data(lots of 0's in data)

# %%
from sklearn.preprocessing import MaxAbsScaler
ma=MaxAbsScaler()

X_train_ma=ma.fit_transform(X_train)
X_test_ma=ma.transform(X_test)

# %%
X_train_ma.shape, X_test_ma.shape
# Out:
# ((320, 2), (80, 2))

# %% [markdown]
# ## Robust Scaler
#
# Robust Scaling is use full if there is outliers in data

# %%
from sklearn.preprocessing import RobustScaler
rs= RobustScaler()
X_train_rs=rs.fit_transform(X_train)
X_test_rs=rs

# %%
X_train_rs.shape, X_test_rs.shape
# Out:
# ((320, 2), (80, 2))
